# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import seaborn as sns
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 587

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Create base URL for open weather map API call
base_url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key

name_city = []
clouds = []
countries = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []

# Create record counter initialized at 1.
record = 1

# Print statement for log.
print("Beginning Data Retrieval")
print('-'*25)

# Loop through all cities in cities list.
for city in cities:
    
    # Try statement to append calls where values are found.
    try:
        response = requests.get(f'{base_url}&q={city}').json()
        name_city.append(response['name'])
        clouds.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        
        print(f'Processing Record {record} | {city}')
        
        # Increase record counter.
        record += 1
        
        # Do not exceed API call limit.
        time.sleep(1.01)
        
    # If no record found for city, then skip.
    except:
        print('City not found. Skipping...')
    continue
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 | waitangi
# Processing Record 2 | acapulco de juarez
# Processing Record 3 | hawaiian paradise park
# Processing Record 4 | tallkayf
# Processing Record 5 | tiksi
# Processing Record 6 | puerto armuelles
# Processing Record 7 | newquay
# Processing Record 8 | stanley
# Processing Record 9 | grytviken
# Processing Record 10 | kodiak
# Processing Record 11 | puerto natales
# Processing Record 12 | port-aux-francais
# Processing Record 13 | kimbe
# Processing Record 14 | carutapera
# Processing Record 15 | aasiaat
# Processing Record 16 | taroa
# Processing Record 17 | bethel
# Processing Record 18 | el granada
# Processing Record 19 | ancud
# Processing Record 20 | nova vicosa
# Processing Record 21 | uturoa
# Processing Record 22 | aksuat
# Processing Record 23 | adamstown
# Processing Record 24 | longyearbyen
# Processing Record 25 | enewetak
# Processing Record 26 | gamay
# Processing Record 27 | bilibino
# City not found. Skipping...
# Processing Record 28 | tobol'sk
# Processing Record 29 | petropavlovsk-kamchatsky
# Processing Record 30 | ghardaia
# Processing Record 31 | invercargill
# Processing Record 32 | morant bay
# Processing Record 33 | chibougamau
# Processing Record 34 | lebu
# Processing Record 35 | torghay
# Processing Record 36 | longboat key
# Processing Record 37 | nar'yan-mar
# Processing Record 38 | jamestown
# Processing Record 39 | port elizabeth
# Processing Record 40 | mount isa
# City not found. Skipping...
# Processing Record 41 | shirgaon
# Processing Record 42 | fort mcmurray
# Processing Record 43 | al mutayrifi
# Processing Record 44 | pangai
# Processing Record 45 | tauranga
# Processing Record 46 | west island
# Processing Record 47 | edinburgh of the seven seas
# Processing Record 48 | blackmans bay
# Processing Record 49 | mios
# Processing Record 50 | kabansk
# Processing Record 51 | albany
# Processing Record 52 | georgetown
# Processing Record 53 | san patricio
# Processing Record 54 | tazovsky
# Processing Record 55 | nemuro
# Processing Record 56 | hermanus
# Processing Record 57 | dhuusamarreeb
# Processing Record 58 | vilyuchinsk
# Processing Record 59 | alcacer do sal
# Processing Record 60 | queenstown
# Processing Record 61 | ataq
# Processing Record 62 | inirida
# Processing Record 63 | tocopilla
# Processing Record 64 | margaret river
# Processing Record 65 | papatowai
# Processing Record 66 | brookings
# Processing Record 67 | ilulissat
# Processing Record 68 | mil'kovo
# Processing Record 69 | bodo
# Processing Record 70 | alice springs
# Processing Record 71 | choix
# Processing Record 72 | port mathurin
# Processing Record 73 | bairnsdale
# Processing Record 74 | zlatograd
# Processing Record 75 | olonkinbyen
# Processing Record 76 | luanda
# Processing Record 77 | arvayheer
# Processing Record 78 | praia da vitoria
# Processing Record 79 | susuman
# Processing Record 80 | bro
# Processing Record 81 | turabah
# Processing Record 82 | aripuana
# Processing Record 83 | lerwick
# Processing Record 84 | byron bay
# Processing Record 85 | college
# Processing Record 86 | taoudenni
# Processing Record 87 | tahoua
# Processing Record 88 | dudinka
# Processing Record 89 | klyuchi
# Processing Record 90 | ilabaya
# Processing Record 91 | bredasdorp
# Processing Record 92 | lata
# Processing Record 93 | hasaki
# Processing Record 94 | iqaluit
# Processing Record 95 | al jawf
# Processing Record 96 | yellowknife
# Processing Record 97 | thompson
# Processing Record 98 | pekanbaru
# City not found. Skipping...
# Processing Record 99 | luganville
# Processing Record 100 | amahai
# Processing Record 101 | chonchi
# Processing Record 102 | polyarnyy
# Processing Record 103 | badger
# Processing Record 104 | tadine
# Processing Record 105 | colonia
# Processing Record 106 | sinabang
# Processing Record 107 | tralee
# Processing Record 108 | ust-nera
# Processing Record 109 | al ghayzah
# Processing Record 110 | mount gambier
# Processing Record 111 | paka
# Processing Record 112 | usinsk
# Processing Record 113 | gilgit
# Processing Record 114 | crane
# Processing Record 115 | talnakh
# Processing Record 116 | ushuaia
# Processing Record 117 | fort wellington
# Processing Record 118 | sretensk
# Processing Record 119 | suntar
# Processing Record 120 | tekman
# Processing Record 121 | belmonte
# Processing Record 122 | inderbor
# Processing Record 123 | westport
# Processing Record 124 | punta arenas
# Processing Record 125 | san julian
# Processing Record 126 | puerto ayora
# Processing Record 127 | margate
# Processing Record 128 | vorgashor
# Processing Record 129 | ocsa
# Processing Record 130 | bhamo
# Processing Record 131 | new plymouth
# Processing Record 132 | coari
# Processing Record 133 | qarqaraly
# Processing Record 134 | carnarvon
# Processing Record 135 | hadibu
# Processing Record 136 | fale old settlement
# Processing Record 137 | howard springs
# Processing Record 138 | porto novo
# Processing Record 139 | chivhu
# Processing Record 140 | new norfolk
# Processing Record 141 | santa marta
# Processing Record 142 | saugor
# Processing Record 143 | arkhangel'sk
# Processing Record 144 | akdepe
# Processing Record 145 | selfoss
# Processing Record 146 | camargo
# Processing Record 147 | lompoc
# City not found. Skipping...
# Processing Record 148 | broken hill
# Processing Record 149 | san antonio de pale
# Processing Record 150 | san fernando de apure
# Processing Record 151 | inongo
# Processing Record 152 | kapuskasing
# Processing Record 153 | borodulikha
# Processing Record 154 | can
# Processing Record 155 | aroma
# Processing Record 156 | muscat
# Processing Record 157 | soio
# Processing Record 158 | whitehorse
# Processing Record 159 | pisco
# Processing Record 160 | kerikeri
# Processing Record 161 | bati
# Processing Record 162 | atafu village
# Processing Record 163 | motueka
# Processing Record 164 | nazarovo
# Processing Record 165 | atherton
# City not found. Skipping...
# Processing Record 166 | port alfred
# Processing Record 167 | middlesboro
# Processing Record 168 | dunedin
# Processing Record 169 | volvera
# Processing Record 170 | tawau
# Processing Record 171 | yasuj
# Processing Record 172 | papao
# Processing Record 173 | ghat
# Processing Record 174 | psyzh
# Processing Record 175 | mahina
# Processing Record 176 | mhamid
# City not found. Skipping...
# Processing Record 177 | tabou
# Processing Record 178 | phan rang-thap cham
# Processing Record 179 | avarua
# Processing Record 180 | udachny
# Processing Record 181 | la ronge
# Processing Record 182 | freetown
# Processing Record 183 | haiku-pauwela
# Processing Record 184 | bardai
# Processing Record 185 | labytnangi
# Processing Record 186 | onega
# Processing Record 187 | nova sintra
# City not found. Skipping...
# Processing Record 188 | kurayoshi
# Processing Record 189 | hamilton
# Processing Record 190 | fiambala
# Processing Record 191 | craig
# Processing Record 192 | great bend
# Processing Record 193 | tura
# Processing Record 194 | kone
# Processing Record 195 | pitimbu
# Processing Record 196 | breckenridge
# Processing Record 197 | sa pa
# Processing Record 198 | dolbeau-mistassini
# Processing Record 199 | brigantine
# Processing Record 200 | doka
# Processing Record 201 | le vauclin
# Processing Record 202 | sitka
# Processing Record 203 | lalago
# Processing Record 204 | palikir - national government center
# Processing Record 205 | neiafu
# Processing Record 206 | black point
# Processing Record 207 | erenhot
# Processing Record 208 | labrador city
# Processing Record 209 | skelleftea
# Processing Record 210 | maine soroa
# Processing Record 211 | mount pearl
# Processing Record 212 | anshun
# Processing Record 213 | weno
# Processing Record 214 | port douglas
# Processing Record 215 | batang
# Processing Record 216 | banda aceh
# Processing Record 217 | anadyr
# Processing Record 218 | vila velha
# Processing Record 219 | geraldton
# Processing Record 220 | isangel
# Processing Record 221 | ribeira grande
# Processing Record 222 | sturgeon bay
# Processing Record 223 | nykvarn
# Processing Record 224 | collie
# Processing Record 225 | ambatondrazaka
# Processing Record 226 | east london
# Processing Record 227 | ciudad lazaro cardenas
# Processing Record 228 | tangalle
# Processing Record 229 | lorengau
# Processing Record 230 | yomju-up
# Processing Record 231 | taltal
# Processing Record 232 | solwezi
# Processing Record 233 | el calafate
# Processing Record 234 | huarmey
# Processing Record 235 | sisimiut
# Processing Record 236 | comodoro rivadavia
# Processing Record 237 | egersund
# Processing Record 238 | ofunato
# Processing Record 239 | touros
# Processing Record 240 | yarmouth
# Processing Record 241 | saldanha
# Processing Record 242 | padang
# Processing Record 243 | sebastopol
# Processing Record 244 | karratha
# Processing Record 245 | callao
# Processing Record 246 | melfi
# Processing Record 247 | isafjordur
# Processing Record 248 | itaituba
# Processing Record 249 | carbonear
# Processing Record 250 | bishkul
# Processing Record 251 | sheringham
# Processing Record 252 | valday
# Processing Record 253 | kaga bandoro
# Processing Record 254 | taro
# Processing Record 255 | salahonda
# Processing Record 256 | st. john's
# Processing Record 257 | moree
# Processing Record 258 | axim
# Processing Record 259 | rubizhne
# Processing Record 260 | tazacorte
# Processing Record 261 | igarka
# Processing Record 262 | klaksvik
# City not found. Skipping...
# Processing Record 263 | saipan
# Processing Record 264 | jumilla
# Processing Record 265 | steinbach
# Processing Record 266 | acarau
# Processing Record 267 | bengkulu
# Processing Record 268 | prince rupert
# Processing Record 269 | coquimbo
# Processing Record 270 | ugoofaaru
# Processing Record 271 | cambria
# Processing Record 272 | ngetkib
# Processing Record 273 | quang ngai
# Processing Record 274 | bubaque
# Processing Record 275 | kayangel
# Processing Record 276 | kozhevnikovo
# Processing Record 277 | sao jose da coroa grande
# Processing Record 278 | baukau
# Processing Record 279 | portel
# Processing Record 280 | chaiyaphum
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 281 | weatherford
# Processing Record 282 | luderitz
# Processing Record 283 | arraial do cabo
# Processing Record 284 | laguna
# Processing Record 285 | constantia
# Processing Record 286 | revda
# Processing Record 287 | kendari
# Processing Record 288 | saint-joseph
# Processing Record 289 | sao joao da barra
# Processing Record 290 | iskateley
# Processing Record 291 | wailua homesteads
# Processing Record 292 | katsuura
# Processing Record 293 | chake chake
# Processing Record 294 | mondariz
# Processing Record 295 | quellon
# City not found. Skipping...
# Processing Record 296 | settat
# Processing Record 297 | codrington
# Processing Record 298 | dedza
# Processing Record 299 | port lincoln
# Processing Record 300 | kuloy
# Processing Record 301 | kuraymah
# Processing Record 302 | chipinge
# Processing Record 303 | nantucket
# Processing Record 304 | east ballina
# Processing Record 305 | keflavik
# Processing Record 306 | bratsk
# Processing Record 307 | yatou
# Processing Record 308 | batouri
# Processing Record 309 | lhokseumawe
# Processing Record 310 | bikenibeu village
# Processing Record 311 | kapsabet
# City not found. Skipping...
# Processing Record 312 | kourou
# Processing Record 313 | sinop
# Processing Record 314 | cabo san lucas
# Processing Record 315 | saurimo
# Processing Record 316 | zavodoukovsk
# Processing Record 317 | bandon
# Processing Record 318 | stephenville
# Processing Record 319 | kaa-khem
# Processing Record 320 | maintirano
# Processing Record 321 | plouzane
# Processing Record 322 | kingscliff
# Processing Record 323 | kurchatov
# Processing Record 324 | joaquin v. gonzalez
# Processing Record 325 | bor
# Processing Record 326 | ramban
# Processing Record 327 | luchegorsk
# Processing Record 328 | mejit
# Processing Record 329 | rehoboth
# Processing Record 330 | mahibadhoo
# Processing Record 331 | imbituba
# Processing Record 332 | kirakira
# Processing Record 333 | magnanville
# Processing Record 334 | kalmunai
# Processing Record 335 | nouadhibou
# Processing Record 336 | amga
# Processing Record 337 | seven pagodas
# Processing Record 338 | sharm el-sheikh
# Processing Record 339 | gujba
# Processing Record 340 | huitel
# Processing Record 341 | bel ombre
# Processing Record 342 | afaahiti
# Processing Record 343 | north bend
# Processing Record 344 | suwayr
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 345 | undurkhaan
# Processing Record 346 | thunder bay
# Processing Record 347 | altus
# Processing Record 348 | elin pelin
# Processing Record 349 | pula
# Processing Record 350 | sale
# City not found. Skipping...
# Processing Record 351 | weligama
# Processing Record 352 | bako
# Processing Record 353 | minas de marcona
# Processing Record 354 | santa ana
# Processing Record 355 | sungai penuh
# Processing Record 356 | surakarta
# Processing Record 357 | lushun
# Processing Record 358 | talakan
# City not found. Skipping...
# Processing Record 359 | eforie sud
# Processing Record 360 | greenville
# Processing Record 361 | kuhdasht
# Processing Record 362 | brooks
# Processing Record 363 | tarma
# Processing Record 364 | narok
# Processing Record 365 | tolanaro
# Processing Record 366 | rabaul
# Processing Record 367 | copala
# Processing Record 368 | hobyo
# Processing Record 369 | labuan
# Processing Record 370 | villa el carmen
# Processing Record 371 | kantagi
# Processing Record 372 | valley city
# Processing Record 373 | al qadarif
# Processing Record 374 | beau vallon
# City not found. Skipping...
# Processing Record 375 | berezovyy
# Processing Record 376 | hue
# City not found. Skipping...
# Processing Record 377 | gbely
# Processing Record 378 | mareeba
# Processing Record 379 | colares
# Processing Record 380 | utrik
# Processing Record 381 | yambio
# Processing Record 382 | springbok
# Processing Record 383 | sola
# Processing Record 384 | la paz
# Processing Record 385 | mata-utu
# Processing Record 386 | varva
# City not found. Skipping...
# Processing Record 387 | camocim
# Processing Record 388 | arica
# Processing Record 389 | chegdomyn
# Processing Record 390 | fort bragg
# Processing Record 391 | tateyama
# Processing Record 392 | greymouth
# Processing Record 393 | tyukhtet
# Processing Record 394 | leshan
# Processing Record 395 | gandai
# Processing Record 396 | antofagasta
# Processing Record 397 | severo-yeniseyskiy
# Processing Record 398 | kristiansund
# Processing Record 399 | tabas
# Processing Record 400 | ust'-barguzin
# City not found. Skipping...
# Processing Record 401 | lihue
# Processing Record 402 | mirny
# City not found. Skipping...
# Processing Record 403 | ishigaki
# Processing Record 404 | kailua-kona
# Processing Record 405 | panagar
# Processing Record 406 | vadso
# Processing Record 407 | cedeira
# Processing Record 408 | khandyga
# Processing Record 409 | renqiu
# Processing Record 410 | concepcion
# Processing Record 411 | salekhard
# Processing Record 412 | khovd
# Processing Record 413 | bhimunipatnam
# Processing Record 414 | puerto baquerizo moreno
# Processing Record 415 | mandalgovi
# Processing Record 416 | tuy hoa
# City not found. Skipping...
# Processing Record 417 | diu
# Processing Record 418 | ghadamis
# Processing Record 419 | nang rong
# Processing Record 420 | yanam
# Processing Record 421 | tsurugi-asahimachi
# Processing Record 422 | pathein
# Processing Record 423 | sidrolandia
# Processing Record 424 | vorkuta
# Processing Record 425 | guerrero negro
# Processing Record 426 | retreat
# Processing Record 427 | tulun
# Processing Record 428 | guilin
# Processing Record 429 | asau
# Processing Record 430 | kampene
# Processing Record 431 | portland
# Processing Record 432 | al qubbah
# Processing Record 433 | quimili
# Processing Record 434 | zachary
# Processing Record 435 | aykhal
# Processing Record 436 | howrah
# Processing Record 437 | am timan
# Processing Record 438 | hacienda huancane
# Processing Record 439 | kalat
# Processing Record 440 | tondon
# Processing Record 441 | nedryhayliv
# Processing Record 442 | ouarzazat
# Processing Record 443 | garachico
# Processing Record 444 | la passe
# Processing Record 445 | galliano
# Processing Record 446 | macapa
# Processing Record 447 | nizhniy lomov
# Processing Record 448 | salinopolis
# Processing Record 449 | bagan
# Processing Record 450 | atakpame
# Processing Record 451 | timimoun
# Processing Record 452 | port macquarie
# Processing Record 453 | saint-francois
# Processing Record 454 | sangla hill
# Processing Record 455 | val-d'or
# Processing Record 456 | hithadhoo
# Processing Record 457 | makurazaki
# Processing Record 458 | fuengirola
# Processing Record 459 | aioun
# Processing Record 460 | arno
# Processing Record 461 | andijon
# Processing Record 462 | manaure
# Processing Record 463 | tchibanga
# Processing Record 464 | holualoa
# Processing Record 465 | pariaman
# Processing Record 466 | flying fish cove
# Processing Record 467 | itoman
# Processing Record 468 | keetmanshoop
# Processing Record 469 | faya-largeau
# Processing Record 470 | ostersund
# Processing Record 471 | cordoba
# Processing Record 472 | lazaro cardenas
# Processing Record 473 | suva
# Processing Record 474 | luwingu
# Processing Record 475 | tafuna
# Processing Record 476 | chui
# Processing Record 477 | newport
# Processing Record 478 | maqat
# City not found. Skipping...
# Processing Record 479 | aden
# Processing Record 480 | rovinj
# Processing Record 481 | nogliki
# Processing Record 482 | kingston
# Processing Record 483 | pangoa
# Processing Record 484 | san luis de la loma
# Processing Record 485 | sos'va
# Processing Record 486 | nieuw amsterdam
# Processing Record 487 | caleta de carquin
# Processing Record 488 | kalavad
# Processing Record 489 | lianhe
# Processing Record 490 | tarragona
# Processing Record 491 | znamenskoye
# Processing Record 492 | chacabuco
# Processing Record 493 | chengdu
# Processing Record 494 | pahlgam
# Processing Record 495 | lubang
# Processing Record 496 | saint-philippe
# Processing Record 497 | banlung
# Processing Record 498 | acajutla
# Processing Record 499 | velikiy novgorod
# Processing Record 500 | gamba
# Processing Record 501 | boende
# Processing Record 502 | djambala
# Processing Record 503 | ulladulla
# Processing Record 504 | mthatha
# Processing Record 505 | guercif
# Processing Record 506 | dar chioukh
# Processing Record 507 | yanaul
# Processing Record 508 | pankovka
# Processing Record 509 | borogontsy
# Processing Record 510 | ar rutbah
# Processing Record 511 | qaqortoq
# Processing Record 512 | vernon
# Processing Record 513 | kill devil hills
# Processing Record 514 | eldama ravine
# Processing Record 515 | palmer
# Processing Record 516 | hirara
# City not found. Skipping...
# Processing Record 517 | oshnaviyeh
# Processing Record 518 | machico
# Processing Record 519 | houghton
# Processing Record 520 | krasnohrad
# Processing Record 521 | kapa'a
# Processing Record 522 | qamdo
# Processing Record 523 | camana
# Processing Record 524 | iranshahr
# Processing Record 525 | nyurba
# Processing Record 526 | barcelos
# Processing Record 527 | ceeldheer
# Processing Record 528 | nuku'alofa
# Processing Record 529 | vevcani
# Processing Record 530 | yuzhno-kurilsk
# Processing Record 531 | visbek
# Processing Record 532 | bratske
# Processing Record 533 | altay
# Processing Record 534 | belomorsk
# Processing Record 535 | buka
# Processing Record 536 | nago
# Processing Record 537 | kununurra
# City not found. Skipping...
# Processing Record 538 | ukiah
# Processing Record 539 | nossa senhora da gloria
# Processing Record 540 | cascais
# Processing Record 541 | khash
# Processing Record 542 | paradip garh
# Processing Record 543 | plastun
# Processing Record 544 | bakal
# Processing Record 545 | cururupu
# Processing Record 546 | ylitornio
# Processing Record 547 | aral
# Processing Record 548 | rongelap
# City not found. Skipping...
# Processing Record 549 | soc trang
# Processing Record 550 | el bauga
# Processing Record 551 | waingapu
# Processing Record 552 | qala i naw
# Processing Record 553 | edenbridge
# Processing Record 554 | bamboo flat
# Processing Record 555 | vodnyy
# Processing Record 556 | puerto lempira
# Processing Record 557 | posto fiscal rolim de moura
# Processing Record 558 | rayachoti
# Processing Record 559 | fortuna
# Processing Record 560 | castillos
# Processing Record 561 | homer

# %%
# Create values dictionary from API call lists.
weatherdata = {
    'City': name_city,
    'Cloudiness': clouds,
    'Country': countries,
    'Date': dates,
    'Humidity': humidities,
    'Lat': lats,
    'Lng': lngs,
    'Max Temperature': max_temps,
    'Wind Speed': wind_speeds
}

# Create new DF for values in dictionary.
df_weather = pd.DataFrame(weatherdata)

# Display count of weather values per column.
df_weather.count()
# Out:
# City               561
# Cloudiness         561
# Country            561
# Date               561
# Humidity           561
# Lat                561
# Lng                561
# Max Temperature    561
# Wind Speed         561
# dtype: int64

# %%
# Display sample data
df_weather.head()
# Out:
#                      City  Cloudiness Country        Date  Humidity      Lat  \
# 0                Waitangi         100      NZ  1681930688        93 -43.9535
# 1      Acapulco de Juárez          61      MX  1681930690        56  16.8634
# 2  Hawaiian Paradise Park          20      US  1681930691        95  19.5933
# 3                Tallkayf         100      IQ  1681930692        40  36.4894
# 4                   Tiksi         100      RU  1681930670       100  71.6872
#
#         Lng  Max Temperature  Wind Speed
# 0 -176.5597            16.01        3.58
# 1  -99.8901            30.67        4.52
# 2 -154.9731            23.83        6.69
# 3   43.1192            22.95        2.66
# 4  128.8694           -23.10        1.67

# %%
df_weather.to_csv('output_data/weather_data.csv')

# %%
df_weather = df_weather.rename(index={'Unnamed: 0': 'City ID'})
# Read saved data
#city_data_df = pd.read_csv("weather_data.csv", index_col="City ID")

# Display sample data
df_weather.head()
# Out:
#                      City  Cloudiness Country        Date  Humidity      Lat  \
# 0                Waitangi         100      NZ  1681930688        93 -43.9535
# 1      Acapulco de Juárez          61      MX  1681930690        56  16.8634
# 2  Hawaiian Paradise Park          20      US  1681930691        95  19.5933
# 3                Tallkayf         100      IQ  1681930692        40  36.4894
# 4                   Tiksi         100      RU  1681930670       100  71.6872
#
#         Lng  Max Temperature  Wind Speed
# 0 -176.5597            16.01        3.58
# 1  -99.8901            30.67        4.52
# 2 -154.9731            23.83        6.69
# 3   43.1192            22.95        2.66
# 4  128.8694           -23.10        1.67

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(df_weather['Lat'], df_weather['Max Temperature'], marker='o', s=20, c='b', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Max Temperature')
plt.ylabel('Max Temperature (C)')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(df_weather['Lat'], df_weather['Humidity'], marker='o', s=20, c='green', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity')
plt.ylabel('Humidity')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(df_weather['Lat'], df_weather['Cloudiness'], marker='o', s=20, c='green', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness')
plt.ylabel('Cloudiness')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(df_weather['Lat'], df_weather['Wind Speed'], marker='o', s=20, c='green', edgecolors='black', alpha=.75)

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(df_weather, x_col, y_col):
    sns.regplot(x=df_weather[x_col], y=df_weather[y_col])

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
threshold = 0
north_hem_df = df_weather[df_weather['Lat'] >= threshold]

# Display sample data
north_hem_df.head()
# Out:
#                      City  Cloudiness Country        Date  Humidity      Lat  \
# 1      Acapulco de Juárez          61      MX  1681930690        56  16.8634
# 2  Hawaiian Paradise Park          20      US  1681930691        95  19.5933
# 3                Tallkayf         100      IQ  1681930692        40  36.4894
# 4                   Tiksi         100      RU  1681930670       100  71.6872
# 5        Puerto Armuelles         100      PA  1681930695        61   8.2833
#
#         Lng  Max Temperature  Wind Speed
# 1  -99.8901            30.67        4.52
# 2 -154.9731            23.83        6.69
# 3   43.1192            22.95        2.66
# 4  128.8694           -23.10        1.67
# 5  -82.8667            32.99        4.56

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
south_hem_df = df_weather[df_weather['Lat'] <= threshold]

# Display sample data
south_hem_df.head()
# Out:
#                  City  Cloudiness Country        Date  Humidity      Lat  \
# 0            Waitangi         100      NZ  1681930688        93 -43.9535
# 8           Grytviken         100      GS  1681930699        93 -54.2811
# 10     Puerto Natales          75      CL  1681930702        50 -51.7236
# 11  Port-aux-Français          74      TF  1681930669        76 -49.3500
# 12              Kimbe          89      PG  1681930705        93  -5.5502
#
#          Lng  Max Temperature  Wind Speed
# 0  -176.5597            16.01        3.58
# 8   -36.5092             3.07        1.90
# 10  -72.4875            13.25       15.95
# 11   70.2167             5.02       16.37
# 12  150.1429            23.96        1.50

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
create_linear_regression_plot(north_hem_df,"Lat", "Max Temperature")

plt.title('City Latitude vs. Northern Hemisphere Temperatures')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig5.png")

# %%
# Linear regression on Southern Hemisphere
create_linear_regression_plot(south_hem_df,"Lat", "Max Temperature")

plt.title('City Latitude vs. Southern Hemisphere Temperatures')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig6.png")

# %% [markdown]
# **Discussion about the linear relationship:**
# Based on the linear regression of the northern and southern hemisphere, it can be concluded that as latitudes increase, growing farther away from "0", the max temperatures of cities in the northern hemisphere decreases.
#
# The inverse effect is true for the southern hemisphere, for when latitudes increase towards "0", max temperatures also increases
#
# This is because "0" indicates the equator, and as the latitude increases, cities are more north of the equator, thus becoming colder. And as the latitude decreases away from the equator going further south, cities in the southern hemisphere also become colder.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(north_hem_df,"Lat", "Humidity")

plt.title('City Latitude vs. Northern Hemisphere Humidity')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig6.png")

# %%
# Southern Hemisphere
create_linear_regression_plot(south_hem_df,"Lat", "Humidity")

plt.title('City Latitude vs. Southern Hemisphere Humidity')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig7.png")

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There does not appear to be a strong relationship between latitude and humidity. however there is a slightly larger cluster of northern hemisphere cities with high humidity (above 60% humidity). This is contrary to meteorological findings that prove that as latitudes go closer to the poles, the atmosphere is less humid as a result of it being harder for cold air to hold moisture compared to hotter climates near the equator

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(north_hem_df,"Lat", "Cloudiness")

plt.title('City Latitude vs. Northern Hemisphere Cloudiness')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig8.png")

# %%
# Southern Hemisphere
create_linear_regression_plot(south_hem_df,"Lat", "Cloudiness")

plt.title('City Latitude vs. Southern Hemisphere Humidity')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig9.png")

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is no strong relationship between latitude and cloudiness. However, it is interesting to see a strong band of cities near 0, 80, and 90% cloudiness

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
create_linear_regression_plot(north_hem_df,"Lat", "Wind Speed")

plt.title('City Latitude vs. Northern Hemisphere Wind Speeds')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig10.png")

# %%
# Southern Hemisphere
create_linear_regression_plot(south_hem_df,"Lat", "Wind Speed")

plt.title('City Latitude vs. Southern Hemisphere Wind Speeds')
plt.ylabel('Wind Speed')
plt.xlabel('Latitude')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig11.png")

# %% [markdown]
# **Discussion about the linear relationship:**
#
# There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind
